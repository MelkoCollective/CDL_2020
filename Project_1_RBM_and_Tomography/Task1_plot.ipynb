# %%
#Work done by Santanu Ganguly and Claudio Giampa'
#test02.csv contains the data we obtained from our experiments which we 
# %matplotlib inline

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.genfromtxt("test02.csv",delimiter=",",names="['x','y']")
plt.plot(data['x'],data['y'])
plt.xlabel('Radius r')
plt.ylabel('Bond Energy')
# Out:
# Text(0, 0.5, 'Bond Energy')
