# %% [markdown]
# # Task 1
#
# A template code for calculating FCFs for $H_2$ - $H_2^+$ using the harmonic oscillator approximation.
#
# Imports:

# %%
import numpy as np
import matplotlib.pyplot as plt

from FCF_helper_rw import FCFSpec

# %% [markdown]
# Initialize the `FCFSpec` object. Modify `n_0_max` and `n_p_max` (the maximum vibrational states of $H_2$ and $H_2^+$ that we'll look at calculating FCFs for) in order to get 10 transitions starting from n_0=0.

# %%
n_0_max = 20
n_p_max = 20


## The change is implemented in the file. 
fcfspec = FCFSpec(n_0_max, n_p_max)

# %% [markdown]
# Calculate all the FCFs and print the results.

# %%
spectrum = fcfspec.spectrum_analysis()
import pandas as pd
df = pd.DataFrame(spectrum, columns=['n_0','n_p','FCF','DeltaE'])
df.sort_values('DeltaE', inplace=True)
df.head()
# print("n_0\t\t n_p\t\t FCF\t\t DeltaE")
# print(spectrum)
# Out:
#       n_0  n_p       FCF        DeltaE
# 420  20.0  0.0  0.000182 -89058.933108
# 421  20.0  1.0  0.003388 -86736.933108
# 399  19.0  0.0  0.000366 -84657.933108
# 422  20.0  2.0  0.026927 -84414.933108
# 400  19.0  1.0  0.006250 -82335.933108

# %%
plt.scatter(spectrum[:,-1],spectrum[:,-2])

# %%
pnt = df[(df['n_0']==0)  & (df['n_p']==10)].values[0]
fig = plt.figure(figsize=(14,6))
ax = fig.add_subplot(111)
ax.scatter(pnt[-1], pnt[-2], c='r')
XY.plot(x = 'DeltaE', y= 'FCF', kind='line' , ax=ax, marker='*')
plt.show()

# %%
df[(df['n_0']==0)  & (df['n_p']==10)]
# Out:
#     n_0   n_p      FCF         DeltaE
# 10  0.0  10.0  0.000254  22181.066892

# %% [markdown]
# # Task 2
#
# After compiling the c++ file and running the output program on V3, we pass the result here to plot.

# %%
spect = np.loadtxt('Task2Code/V3.sticks.out')

# %%
plt.scatter(*spect.T)

# %%
spect = np.loadtxt('Task2Code/V3.spec.out')

# %%
plt.plot(*spect.T)

# %% [markdown]
# # Task 3
