# %% [markdown]
# # Quantum Circuits for Calculating Molecules PES
#
#
# We want to use a Quantum computer to compute the PES of a molecule.
#
# To do so we must first obtain the molecules Hamiltonian which describes its energy. Because it is too large and complex to compute as is, we prepare a list of transformations (seen in step 4 and step 5) so that we can create circuits that can calculate energies.
#
# In this notebook we are showing how two cooperating techniques can be used to create our circuits:
#
#     Qubit Coupled Cluster (QCC) creating ansatz
#     Qubit-wise commuting (QWC) creating a transformed list of quantum computable circuits

# %% [markdown]
# ## In this notebook
#
# ### $H_2$ Circuits
#
# By default this notebook will run quantum circuits for the H2 molecule. There are 2 circuits to run
# It will:
#
#     prepare Molecule Ansatz and Entanglers using QCC from Step 3 and QWC and Unitaries from Step 4
#     prepare the Individual Circuits to run
#     run the circuits to calculate PES
#
# ### $H_2O$ Circuits
#
# One can select the H2O run. There are 16 circuits to run. The same process as above will be followed.
#
# ### Other molecules
#
# Other molecules were experimented but results were not available at the time of submission. However, the code intent is to allow for other molecules.

# %% [markdown]
# One can run the same experiment on a real quantum computer through IBM Quantum Experience (ibmq). After activating your account here (https://quantum-computing.ibm.com/login), copy the API token and execute the commented block below.

# %%
useIBM = False   # By default Quantum hardware is off. To use it, change to True and provide credentials
from qiskit import IBMQ
if ( useIBM ):
    IBMQ.save_account('')

# %% [markdown]
# ## Imports
#
# ### MeasurementUnitaryGenerator Import
#
# The module was created in Step 4. Details can be viewed in the Task 4 notebook

# %%
import tequila as tq
from utility import *
from tqdm.auto import tqdm # pip install tqdm
from MeasurementUnitaryGenerator import MeasurementUnitaryGenerator
from quantumPES import quantumPES

# %% [markdown]
# # Processing Zone

# %% [markdown]
# # $H_2$

# %%
# Create a qPES object

obj = quantumPES()

# H2
obj.prepareMolecule('h2', geometry=2.5, n_ents = 1, qubit_transf = "jw", verbose=False)
obj.prepareCircuits()

# To use the IBMQ machines, activate your account at the start of the notebook and pick an appropriate device 
if ( useIBM ):
    obj.runCircuits(useIBM=True, device="ibmq_london")
else:
    obj.runCircuits()
# Out:
# 1) Initialise the molecule object in a given basis and with a provided mapping
# 	4 orbitals
# 2) Optionally apply tapering
# 	1 orbitals
# 3) Get commuting groups
# 	2 commuting groups, a 1.50 x reduction from 3 terms
# 4) For each commuting group get the unitary for transforming to qwc
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# 5) Apply unitaries to get the qwcs
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# 6) Get unitaries for rotating everything to the measurable z-basis
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# 7) Finally, apply latter unitaries to move all qwc groups to z-basis
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 18 expectationvalues
#
# active variables : 9
#
# E=-1.11734903  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.0}  samples= None
# E=-1.13578343  angles= {beta_0: 3.1415926237874707, gamma_0: 0.0, beta_1: 3.1415926237874707, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.179000586271286}  samples= None
# E=-1.13618943  angles= {beta_0: 3.1415926237874707, gamma_0: 0.0, beta_1: 3.1415926237874707, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.20999452188754272}  samples= None
# E=-1.13618945  angles= {beta_0: 3.1415926237874707, gamma_0: 0.0, beta_1: 3.1415926237874707, gamma_1: 0.0, beta_2: 0.0, gamma_2: 0.0, beta_3: 0.0, gamma_3: 0.0, tau_0: 0.20973450230438037}  samples= None
# Optimization terminated successfully.
#          Current function value: -1.136189
#          Iterations: 3
#          Function evaluations: 4
#          Gradient evaluations: 4
#
# =======================================
#  circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Exp-Pauli(target=(0, 1, 2, 3), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(2)X(3))
#
# =======================================
#
# uqwcs..................................
# X(0)
# uqwcs..................................
# Z(0)
# 2 Circuits generated
# Constructing circuit(s) for H2
# ============= 2 Circuits to execute =============
# Circuit # 0
#      ┌────────────────────┐┌─────────────────────┐   ┌───┐                   »
# q_0: ┤ RX(f((beta_0,))_0) ├┤ RZ(f((gamma_0,))_1) ├───┤ H ├──────■────────────»
#      ├────────────────────┤├─────────────────────┤┌──┴───┴───┐┌─┴─┐          »
# q_1: ┤ RX(f((beta_1,))_2) ├┤ RZ(f((gamma_1,))_3) ├┤ RX(pi/2) ├┤ X ├──■───────»
#      ├────────────────────┤├─────────────────────┤└──┬───┬───┘└───┘┌─┴─┐     »
# q_2: ┤ RX(f((beta_2,))_4) ├┤ RZ(f((gamma_2,))_5) ├───┤ H ├─────────┤ X ├──■──»
#      ├────────────────────┤├─────────────────────┤   ├───┤         └───┘┌─┴─┐»
# q_3: ┤ RX(f((beta_3,))_6) ├┤ RZ(f((gamma_3,))_7) ├───┤ H ├──────────────┤ X ├»
#      └────────────────────┘└─────────────────────┘   └───┘              └───┘»
# c_0: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_1: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_2: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_3: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# «                                             ┌───┐    ┌───────────────────┐
# «q_0: ─────────────────────────────────■──────┤ H ├────┤ RX(f((tau_0,))_9) ├
# «                                    ┌─┴─┐┌───┴───┴───┐└───────────────────┘
# «q_1: ────────────────────────────■──┤ X ├┤ RX(-pi/2) ├─────────────────────
# «                               ┌─┴─┐├───┤└───────────┘
# «q_2: ───────────────────────■──┤ X ├┤ H ├──────────────────────────────────
# «     ┌───────────────────┐┌─┴─┐├───┤└───┘
# «q_3: ┤ RZ(f((tau_0,))_8) ├┤ X ├┤ H ├───────────────────────────────────────
# «     └───────────────────┘└───┘└───┘
# «c_0: ══════════════════════════════════════════════════════════════════════
# «
# «c_1: ══════════════════════════════════════════════════════════════════════
# «
# «c_2: ══════════════════════════════════════════════════════════════════════
# «
# «c_3: ══════════════════════════════════════════════════════════════════════
# «
# Calculated E_sim as :  -0.783792654277352
# Circuit # 1
#      ┌────────────────────┐┌─────────────────────┐   ┌───┐                   »
# q_0: ┤ RX(f((beta_0,))_0) ├┤ RZ(f((gamma_0,))_1) ├───┤ H ├──────■────────────»
#      ├────────────────────┤├─────────────────────┤┌──┴───┴───┐┌─┴─┐          »
# q_1: ┤ RX(f((beta_1,))_2) ├┤ RZ(f((gamma_1,))_3) ├┤ RX(pi/2) ├┤ X ├──■───────»
#      ├────────────────────┤├─────────────────────┤└──┬───┬───┘└───┘┌─┴─┐     »
# q_2: ┤ RX(f((beta_2,))_4) ├┤ RZ(f((gamma_2,))_5) ├───┤ H ├─────────┤ X ├──■──»
#      ├────────────────────┤├─────────────────────┤   ├───┤         └───┘┌─┴─┐»
# q_3: ┤ RX(f((beta_3,))_6) ├┤ RZ(f((gamma_3,))_7) ├───┤ H ├──────────────┤ X ├»
#      └────────────────────┘└─────────────────────┘   └───┘              └───┘»
# c_0: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_1: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_2: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# c_3: ════════════════════════════════════════════════════════════════════════»
#                                                                              »
# «                                             ┌───┐    ┌───────────────────┐
# «q_0: ─────────────────────────────────■──────┤ H ├────┤ RZ(f((tau_0,))_9) ├
# «                                    ┌─┴─┐┌───┴───┴───┐└───────────────────┘
# «q_1: ────────────────────────────■──┤ X ├┤ RX(-pi/2) ├─────────────────────
# «                               ┌─┴─┐├───┤└───────────┘
# «q_2: ───────────────────────■──┤ X ├┤ H ├──────────────────────────────────
# «     ┌───────────────────┐┌─┴─┐├───┤└───┘
# «q_3: ┤ RZ(f((tau_0,))_8) ├┤ X ├┤ H ├───────────────────────────────────────
# «     └───────────────────┘└───┘└───┘
# «c_0: ══════════════════════════════════════════════════════════════════════
# «
# «c_1: ══════════════════════════════════════════════════════════════════════
# «
# «c_2: ══════════════════════════════════════════════════════════════════════
# «
# «c_3: ══════════════════════════════════════════════════════════════════════
# «
# Calculated E_sim as :  -0.783792654277352

# %% [markdown]
# # $H_2O$

# %%
obj = quantumPES()

# H2O
        
obj.prepareMolecule("h2o", geometry=1,  n_ents = 6, basis="6-31g", active_orbitals = {'B1':[0,1], 'A1':[2,3]}, qubit_transf = "jw")
obj.prepareCircuits()

# WARNING: Running H2O on the quantum harware will generate a large number of sequential tasks in the range of 
# about 15 jobs for each 16 circuits. A dedicated machine is desirable for this problem size.

# To use the IBMQ machines, activate your account at the start of the notebook and pick an appropriate device 
if ( useIBM ):
    obj.runCircuits(useIBM=True, device="ibmq_london")
else:
    obj.runCircuits()

#obj.prepareEntanglers("lih")
#obj.prepareEntanglers("h4")
#obj.prepareEntanglers("n2")
#obj.prepareEntanglers("nh3")
# Out:
# Mapping selected: jw
# 1) Initialise the molecule object in a given basis and with a provided mapping
# 	14 orbitals
# 2) Optionally apply tapering
# 	10 orbitals
# More than 8 orbitals: skipping steps 3), 4) and 5) and directly getting qwc groups
# 	200 QWC groups, a 5.17 x reduction from 1035 terms
# 6) Get unitaries for rotating everything to the measurable z-basis
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# 7) Finally, apply latter unitaries to move all qwc groups to z-basis
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# Obtained geometry for h2o is 1
#
#
# Calculating QCC for  H2O
# Basis: 6-31g
# Geometry: 1
# Entanglers: 6
# Active Orbitals: {'B1': [0, 1], 'A1': [2, 3]}
# There are known issues with some psi4 methods and frozen virtual orbitals. Proceed with fingers crossed for hf.
# There are known issues with some psi4 methods and frozen virtual orbitals. Proceed with fingers crossed for fci.
#
# Hamiltonian has 185 terms
#
# Full QCC Circuit from Step 3:
#  circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Rx(target=(4,), parameter=beta_4)
# Rz(target=(4,), parameter=gamma_4)
# Rx(target=(5,), parameter=beta_5)
# Rz(target=(5,), parameter=gamma_5)
# Rx(target=(6,), parameter=beta_6)
# Rz(target=(6,), parameter=gamma_6)
# Rx(target=(7,), parameter=beta_7)
# Rz(target=(7,), parameter=gamma_7)
# Exp-Pauli(target=(0, 1, 6, 7), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(6)X(7))
# Exp-Pauli(target=(0, 3, 5, 6), control=(), parameter=tau_1, paulistring=X(0)Y(3)X(5)X(6))
# Exp-Pauli(target=(1, 2, 4, 7), control=(), parameter=tau_2, paulistring=X(1)Y(2)X(4)X(7))
# Exp-Pauli(target=(2, 3, 4, 5), control=(), parameter=tau_3, paulistring=X(2)Y(3)X(4)X(5))
# Exp-Pauli(target=(0, 1, 4, 5), control=(), parameter=tau_4, paulistring=X(0)Y(1)X(4)X(5))
# Exp-Pauli(target=(2, 3, 6, 7), control=(), parameter=tau_5, paulistring=X(2)Y(3)X(6)X(7))
#
# Initial Values: {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.0, tau_1: 0.0, tau_2: 0.0, tau_3: 0.0, tau_4: 0.0, tau_5: 0.0}
# Optimizer: <class 'tequila.optimizers.optimizer_scipy.OptimizerSciPy'>
# backend         : qulacs
# samples         : None
# save_history    : True
# noise           : None
#
# Method          : BFGS
# Objective       : 1 expectationvalues
# gradient        : 44 expectationvalues
#
# active variables : 22
#
# E=-75.98071144  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.0, tau_1: 0.0, tau_2: 0.0, tau_3: 0.0, tau_4: 0.0, tau_5: 0.0}  samples= None
# E=-75.98783364  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.07584381103515625, tau_1: 0.037105560302734375, tau_2: 0.037105560302734375, tau_3: 0.030994415283203125, tau_4: 0.030078887939453125, tau_5: 0.02489471435546875}  samples= None
# E=-75.98857329  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.10182924911229851, tau_1: 0.05852392400836017, tau_2: 0.05929046375096231, tau_3: 0.046904115611281404, tau_4: 0.04177333199687153, tau_5: 0.0349288019865621}  samples= None
# E=-75.98858260  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09969372766103793, tau_1: 0.060473123892992676, tau_2: 0.06154808363690651, tau_3: 0.04783285764604096, tau_4: 0.04149071210908681, tau_5: 0.034615428738700584}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09850072062214467, tau_1: 0.06125613956121948, tau_2: 0.06252892067861264, tau_3: 0.04818379433559183, tau_4: 0.04135121252205053, tau_5: 0.034404300286443194}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.0984869336458491, tau_1: 0.06124525470501602, tau_2: 0.06253742671112356, tau_3: 0.048180081498317005, tau_4: 0.04137752126121587, tau_5: 0.03439993287674868}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09849193269574927, tau_1: 0.061238181671214226, tau_2: 0.06253665557377065, tau_3: 0.04817439604998531, tau_4: 0.04138965302216318, tau_5: 0.034399771079268934}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09848920158699441, tau_1: 0.0612383170286305, tau_2: 0.06253687289527793, tau_3: 0.04817718311964485, tau_4: 0.04138989663016978, tau_5: 0.03439978336760684}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09848627630925609, tau_1: 0.06123815999684302, tau_2: 0.06253679338436924, tau_3: 0.048177173613686036, tau_4: 0.04139000827970867, tau_5: 0.034399694378788766}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09848773419514585, tau_1: 0.06123823825759215, tau_2: 0.06253683301063459, tau_3: 0.0481771783512202, tau_4: 0.04138995263634694, tau_5: 0.03439973872860913}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09848773250658006, tau_1: 0.061238188080661525, tau_2: 0.06253678117517796, tau_3: 0.04817668169551761, tau_4: 0.04138992794429038, tau_5: 0.03439972173637168}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09848772575231689, tau_1: 0.06123798737293902, tau_2: 0.06253657383335144, tau_3: 0.048174695072707246, tau_4: 0.04138982917606416, tau_5: 0.03439965376742187}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09848772919591664, tau_1: 0.061238089701949085, tau_2: 0.06253667954469921, tau_3: 0.0481757079343103, tau_4: 0.041389879532147573, tau_5: 0.03439968842077383}  samples= None
# E=-75.98858369  angles= {beta_0: 3.141592653589793, gamma_0: 0.0, beta_1: 3.141592653589793, gamma_1: 0.0, beta_2: 3.141592653589793, gamma_2: 0.0, beta_3: 3.141592653589793, gamma_3: 0.0, beta_4: 0.0, gamma_4: 0.0, beta_5: 0.0, gamma_5: 0.0, beta_6: 0.0, gamma_6: 0.0, beta_7: 0.0, gamma_7: 0.0, tau_0: 0.09848772767099051, tau_1: 0.06123804438768713, tau_2: 0.06253663273263975, tau_3: 0.0481752594097328, tau_4: 0.041389857233009204, tau_5: 0.03439967307526167}  samples= None
# Optimization terminated successfully.
#          Current function value: -75.988584
#          Iterations: 9
#          Function evaluations: 14
#          Gradient evaluations: 14
#
# Obtained QCC energy for H2O (6 entanglers): -75.98858368876374
# Compare to FCI energy: -75.98980140961191
#
#
# MCalc Entanglers:
#  [0.24999999999999992 [Y0 X7 Y8 X9] +
# 0.24999999999999992 [Y0 X7 Y8 Z9] +
# 0.24999999999999992 [Y0 X7 Z8 X9] +
# 0.24999999999999992 [Y0 X7 Z8 Z9] +
# 0.24999999999999992 [Y0 Z7 Y8 X9] +
# 0.24999999999999992 [Y0 Z7 Y8 Z9] +
# 0.24999999999999992 [Y0 Z7 Z8 X9] +
# 0.24999999999999992 [Y0 Z7 Z8 Z9] +
# 0.24999999999999992 [Z0 X7 Y8 X9] +
# 0.24999999999999992 [Z0 X7 Y8 Z9] +
# 0.24999999999999992 [Z0 X7 Z8 X9] +
# 0.24999999999999992 [Z0 X7 Z8 Z9] +
# 0.24999999999999992 [Z0 Z7 Y8 X9] +
# 0.24999999999999992 [Z0 Z7 Y8 Z9] +
# 0.24999999999999992 [Z0 Z7 Z8 X9] +
# 0.24999999999999992 [Z0 Z7 Z8 Z9]]
#
# =======================================
#  circuit:
# Rx(target=(0,), parameter=beta_0)
# Rz(target=(0,), parameter=gamma_0)
# Rx(target=(1,), parameter=beta_1)
# Rz(target=(1,), parameter=gamma_1)
# Rx(target=(2,), parameter=beta_2)
# Rz(target=(2,), parameter=gamma_2)
# Rx(target=(3,), parameter=beta_3)
# Rz(target=(3,), parameter=gamma_3)
# Rx(target=(4,), parameter=beta_4)
# Rz(target=(4,), parameter=gamma_4)
# Rx(target=(5,), parameter=beta_5)
# Rz(target=(5,), parameter=gamma_5)
# Rx(target=(6,), parameter=beta_6)
# Rz(target=(6,), parameter=gamma_6)
# Rx(target=(7,), parameter=beta_7)
# Rz(target=(7,), parameter=gamma_7)
# Exp-Pauli(target=(0, 1, 6, 7), control=(), parameter=tau_0, paulistring=X(0)Y(1)X(6)X(7))
# Exp-Pauli(target=(0, 3, 5, 6), control=(), parameter=tau_1, paulistring=X(0)Y(3)X(5)X(6))
# Exp-Pauli(target=(1, 2, 4, 7), control=(), parameter=tau_2, paulistring=X(1)Y(2)X(4)X(7))
# Exp-Pauli(target=(2, 3, 4, 5), control=(), parameter=tau_3, paulistring=X(2)Y(3)X(4)X(5))
# Exp-Pauli(target=(0, 1, 4, 5), control=(), parameter=tau_4, paulistring=X(0)Y(1)X(4)X(5))
# Exp-Pauli(target=(2, 3, 6, 7), control=(), parameter=tau_5, paulistring=X(2)Y(3)X(6)X(7))
#
# =======================================
#
# uzs..................................
# Y(0)X(7)Y(8)X(9)
# uzs..................................
# Y(0)X(7)Y(8)Z(9)
# uzs..................................
# Y(0)X(7)Z(8)X(9)
# uzs..................................
# Y(0)X(7)Z(8)Z(9)
# uzs..................................
# Y(0)Z(7)Y(8)X(9)
# uzs..................................
# Y(0)Z(7)Y(8)Z(9)
# uzs..................................
# Y(0)Z(7)Z(8)X(9)
# uzs..................................
# Y(0)Z(7)Z(8)Z(9)
# uzs..................................
# Z(0)X(7)Y(8)X(9)
# uzs..................................
# Z(0)X(7)Y(8)Z(9)
# uzs..................................
# Z(0)X(7)Z(8)X(9)
# uzs..................................
# Z(0)X(7)Z(8)Z(9)
# uzs..................................
# Z(0)Z(7)Y(8)X(9)
# uzs..................................
# Z(0)Z(7)Y(8)Z(9)
# uzs..................................
# Z(0)Z(7)Z(8)X(9)
# uzs..................................
# Z(0)Z(7)Z(8)Z(9)
# 16 Circuits generated
# Constructing circuit(s) for H2O
# ============= 16 Circuits to execute =============
# Circuit # 0
#       ┌────────────────────┐┌─────────────────────┐    ┌───┐                   »
# q_0: ─┤ RX(f((beta_0,))_0) ├┤ RZ(f((gamma_0,))_1) ├────┤ H ├──────■────────────»
#       ├────────────────────┤├─────────────────────┤ ┌──┴───┴───┐┌─┴─┐          »
# q_1: ─┤ RX(f((beta_1,))_2) ├┤ RZ(f((gamma_1,))_3) ├─┤ RX(pi/2) ├┤ X ├──■───────»
#       ├────────────────────┤├─────────────────────┤ ├──────────┤└───┘  │       »
# q_2: ─┤ RX(f((beta_2,))_4) ├┤ RZ(f((gamma_2,))_5) ├─┤ RX(pi/2) ├───────┼───────»
#       ├────────────────────┤├─────────────────────┤ ├──────────┤       │       »
# q_3: ─┤ RX(f((beta_3,))_6) ├┤ RZ(f((gamma_3,))_7) ├─┤ RX(pi/2) ├───────┼───────»
#       ├────────────────────┤├─────────────────────┤ └──┬───┬───┘       │       »
# q_4: ─┤ RX(f((beta_4,))_8) ├┤ RZ(f((gamma_4,))_9) ├────┤ H ├───────────┼───────»
#      ┌┴────────────────────┤├─────────────────────┴┐   ├───┤           │       »
# q_5: ┤ RX(f((beta_5,))_10) ├┤ RZ(f((gamma_5,))_11) ├───┤ H ├───────────┼───────»
#      ├─────────────────────┤├──────────────────────┤   ├───┤         ┌─┴─┐     »
# q_6: ┤ RX(f((beta_6,))_12) ├┤ RZ(f((gamma_6,))_13) ├───┤ H ├─────────┤ X ├──■──»
#      ├─────────────────────┤├──────────────────────┤   ├───┤         └───┘┌─┴─┐»
# q_7: ┤ RX(f((beta_7,))_14) ├┤ RZ(f((gamma_7,))_15) ├───┤ H ├──────────────┤ X ├»
#      └─────┬──────────┬────┘└──────────────────────┘   └───┘              └───┘»
# q_8: ──────┤ RX(pi/2) ├────────────────────────────────────────────────────────»
#            └──┬───┬───┘                                                        »
# q_9: ─────────┤ H ├────────────────────────────────────────────────────────────»
#               └───┘                                                            »
# c_0: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_1: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_2: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_3: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_4: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_5: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_6: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_7: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_8: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_9: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «                                              ┌───┐    ┌───┐               »
# «q_0: ──────────────────────────────────■──────┤ H ├────┤ H ├──■────────────»
# «                                     ┌─┴─┐┌───┴───┴───┐├───┤  │            »
# «q_1: ─────────────────────────────■──┤ X ├┤ RX(-pi/2) ├┤ H ├──┼────■───────»
# «                                  │  └───┘└───────────┘└───┘  │  ┌─┴─┐     »
# «q_2: ─────────────────────────────┼───────────────────────────┼──┤ X ├──■──»
# «                                  │                         ┌─┴─┐└───┘  │  »
# «q_3: ─────────────────────────────┼─────────────────────────┤ X ├──■────┼──»
# «                                  │                         └───┘  │  ┌─┴─┐»
# «q_4: ─────────────────────────────┼────────────────────────────────┼──┤ X ├»
# «                                  │                              ┌─┴─┐└───┘»
# «q_5: ─────────────────────────────┼──────────────────────────────┤ X ├──■──»
# «                                ┌─┴─┐┌───┐    ┌───┐              └───┘┌─┴─┐»
# «q_6: ────────────────────────■──┤ X ├┤ H ├────┤ H ├───────────────────┤ X ├»
# «     ┌────────────────────┐┌─┴─┐├───┤├───┤    └───┘                   └───┘»
# «q_7: ┤ RZ(f((tau_0,))_16) ├┤ X ├┤ H ├┤ H ├─────────────────────────────────»
# «     └────────────────────┘└───┘└───┘└───┘                                 »
# «q_8: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_9: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «c_0: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_1: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_2: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_3: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_4: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_5: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_6: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_7: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_8: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_9: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                                                             ┌───┐    »
# «q_0: ─────────────────────────────────────────────────■──────┤ H ├────»
# «                                                      │      └───┘    »
# «q_1: ─────────────────────────────────────────────────┼────────■──────»
# «                                                      │      ┌─┴─┐    »
# «q_2: ────────────────────────────────────────────■────┼──────┤ X ├────»
# «                                                 │  ┌─┴─┐┌───┴───┴───┐»
# «q_3: ───────────────────────────────────────■────┼──┤ X ├┤ RX(-pi/2) ├»
# «                                            │  ┌─┴─┐├───┤└───┬───┬───┘»
# «q_4: ──■───────────────────────────────■────┼──┤ X ├┤ H ├────┤ H ├────»
# «       │                               │  ┌─┴─┐├───┤├───┤    └───┘    »
# «q_5: ──┼──────────────────────────■────┼──┤ X ├┤ H ├┤ H ├─────────────»
# «       │  ┌────────────────────┐┌─┴─┐  │  ├───┤├───┤└───┘             »
# «q_6: ──┼──┤ RZ(f((tau_1,))_17) ├┤ X ├──┼──┤ H ├┤ H ├──────────────────»
# «     ┌─┴─┐├────────────────────┤└───┘┌─┴─┐├───┤├───┤                  »
# «q_7: ┤ X ├┤ RZ(f((tau_2,))_18) ├─────┤ X ├┤ H ├┤ H ├──────────────────»
# «     └───┘└────────────────────┘     └───┘└───┘└───┘                  »
# «q_8: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_9: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «c_0: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_1: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_2: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_3: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_4: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_5: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_6: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_7: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_8: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_9: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «         ┌───┐                                                               »
# «q_0: ────┤ H ├──────────────────■────────────────────────────────────────────»
# «         ├───┤    ┌──────────┐┌─┴─┐                                          »
# «q_1: ────┤ H ├────┤ RX(pi/2) ├┤ X ├──────────────────────────────────────────»
# «     ┌───┴───┴───┐└──┬───┬───┘└───┘                                          »
# «q_2: ┤ RX(-pi/2) ├───┤ H ├──────■────────────────────────────────────────────»
# «     └┬──────────┤   └───┘    ┌─┴─┐                                          »
# «q_3: ─┤ RX(pi/2) ├────────────┤ X ├──■────────────────────────────────────■──»
# «      └──────────┘            └───┘┌─┴─┐                                ┌─┴─┐»
# «q_4: ──────────────────────────────┤ X ├──■──────────────────────────■──┤ X ├»
# «                                   └───┘┌─┴─┐┌────────────────────┐┌─┴─┐├───┤»
# «q_5: ───────────────────────────────────┤ X ├┤ RZ(f((tau_3,))_19) ├┤ X ├┤ H ├»
# «                                        └───┘└────────────────────┘└───┘└───┘»
# «q_6: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_7: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_9: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «c_0: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_1: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_2: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_3: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_4: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_5: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_6: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_7: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_8: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_9: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                        »
# «q_0: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_1: ────────────────────■──────────────────────────────────────────────»
# «              ┌───┐      │     ┌───┐                                    »
# «q_2: ──■──────┤ H ├──────┼─────┤ H ├──────────────■─────────────────────»
# «     ┌─┴─┐┌───┴───┴───┐  │  ┌──┴───┴───┐        ┌─┴─┐                   »
# «q_3: ┤ X ├┤ RX(-pi/2) ├──┼──┤ RX(pi/2) ├────────┤ X ├───────────■───────»
# «     ├───┤└───┬───┬───┘┌─┴─┐└──────────┘        └───┘           │       »
# «q_4: ┤ H ├────┤ H ├────┤ X ├─────■──────────────────────────────┼────■──»
# «     ├───┤    └───┘    └───┘   ┌─┴─┐    ┌────────────────────┐  │  ┌─┴─┐»
# «q_5: ┤ H ├─────────────────────┤ X ├────┤ RZ(f((tau_4,))_20) ├──┼──┤ X ├»
# «     └───┘                     └───┘    └────────────────────┘┌─┴─┐└───┘»
# «q_6: ─────────────────────────────────────────────────────────┤ X ├──■──»
# «                                                              └───┘┌─┴─┐»
# «q_7: ──────────────────────────────────────────────────────────────┤ X ├»
# «                                                                   └───┘»
# «q_8: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_9: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «c_0: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_1: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_2: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_3: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_4: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_5: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_6: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_7: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_8: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_9: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «                                    ┌───┐    ┌──────────┐                  »
# «q_0: ────────────────────────■──────┤ H ├────┤ RX(pi/2) ├───────────────■──»
# «                           ┌─┴─┐┌───┴───┴───┐└──────────┘               │  »
# «q_1: ──────────■───────────┤ X ├┤ RX(-pi/2) ├───────────────────────────┼──»
# «               │           └───┘└───────────┘                ┌───┐      │  »
# «q_2: ──────────┼──────────────────────────────────■──────────┤ H ├──────┼──»
# «               │                                ┌─┴─┐    ┌───┴───┴───┐  │  »
# «q_3: ──────────┼──────────────────────■─────────┤ X ├────┤ RX(-pi/2) ├──┼──»
# «             ┌─┴─┐         ┌───┐      │         └───┘    └───────────┘  │  »
# «q_4: ────────┤ X ├─────────┤ H ├──────┼─────────────────────────────────┼──»
# «             ├───┤         └───┘      │                                 │  »
# «q_5: ────────┤ H ├────────────────────┼─────────────────────────────────┼──»
# «             └───┘                  ┌─┴─┐       ┌───┐                   │  »
# «q_6: ────────────────────────■──────┤ X ├───────┤ H ├───────────────────┼──»
# «     ┌────────────────────┐┌─┴─┐    ├───┤       ├───┤                 ┌─┴─┐»
# «q_7: ┤ RZ(f((tau_5,))_21) ├┤ X ├────┤ H ├───────┤ H ├─────────────────┤ X ├»
# «     └────────────────────┘└───┘    └───┘       └───┘                 └───┘»
# «q_8: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_9: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «c_0: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_1: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_2: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_3: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_4: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_5: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_6: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_7: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_8: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_9: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                                                            ┌───────────┐
# «q_0: ────────────────────────────────────────────────■──────┤ RX(-pi/2) ├
# «                                                     │      └───────────┘
# «q_1: ────────────────────────────────────────────────┼───────────────────
# «                                                     │
# «q_2: ────────────────────────────────────────────────┼───────────────────
# «                                                     │
# «q_3: ────────────────────────────────────────────────┼───────────────────
# «                                                     │
# «q_4: ────────────────────────────────────────────────┼───────────────────
# «                                                     │
# «q_5: ────────────────────────────────────────────────┼───────────────────
# «                                                     │
# «q_6: ────────────────────────────────────────────────┼───────────────────
# «                                                   ┌─┴─┐        ┌───┐
# «q_7: ──■────────────────────────────────────■──────┤ X ├────────┤ H ├────
# «     ┌─┴─┐                                ┌─┴─┐┌───┴───┴───┐    └───┘
# «q_8: ┤ X ├──■──────────────────────────■──┤ X ├┤ RX(-pi/2) ├─────────────
# «     └───┘┌─┴─┐┌────────────────────┐┌─┴─┐├───┤└───────────┘
# «q_9: ─────┤ X ├┤ RZ(f((tau_0,))_22) ├┤ X ├┤ H ├──────────────────────────
# «          └───┘└────────────────────┘└───┘└───┘
# «c_0: ════════════════════════════════════════════════════════════════════
# «
# «c_1: ════════════════════════════════════════════════════════════════════
# «
# «c_2: ════════════════════════════════════════════════════════════════════
# «
# «c_3: ════════════════════════════════════════════════════════════════════
# «
# «c_4: ════════════════════════════════════════════════════════════════════
# «
# «c_5: ════════════════════════════════════════════════════════════════════
# «
# «c_6: ════════════════════════════════════════════════════════════════════
# «
# «c_7: ════════════════════════════════════════════════════════════════════
# «
# «c_8: ════════════════════════════════════════════════════════════════════
# «
# «c_9: ════════════════════════════════════════════════════════════════════
# «
# Calculated E_sim as :  -65.60216457035305
# Circuit # 1
#       ┌────────────────────┐┌─────────────────────┐    ┌───┐                   »
# q_0: ─┤ RX(f((beta_0,))_0) ├┤ RZ(f((gamma_0,))_1) ├────┤ H ├──────■────────────»
#       ├────────────────────┤├─────────────────────┤ ┌──┴───┴───┐┌─┴─┐          »
# q_1: ─┤ RX(f((beta_1,))_2) ├┤ RZ(f((gamma_1,))_3) ├─┤ RX(pi/2) ├┤ X ├──■───────»
#       ├────────────────────┤├─────────────────────┤ ├──────────┤└───┘  │       »
# q_2: ─┤ RX(f((beta_2,))_4) ├┤ RZ(f((gamma_2,))_5) ├─┤ RX(pi/2) ├───────┼───────»
#       ├────────────────────┤├─────────────────────┤ ├──────────┤       │       »
# q_3: ─┤ RX(f((beta_3,))_6) ├┤ RZ(f((gamma_3,))_7) ├─┤ RX(pi/2) ├───────┼───────»
#       ├────────────────────┤├─────────────────────┤ └──┬───┬───┘       │       »
# q_4: ─┤ RX(f((beta_4,))_8) ├┤ RZ(f((gamma_4,))_9) ├────┤ H ├───────────┼───────»
#      ┌┴────────────────────┤├─────────────────────┴┐   ├───┤           │       »
# q_5: ┤ RX(f((beta_5,))_10) ├┤ RZ(f((gamma_5,))_11) ├───┤ H ├───────────┼───────»
#      ├─────────────────────┤├──────────────────────┤   ├───┤         ┌─┴─┐     »
# q_6: ┤ RX(f((beta_6,))_12) ├┤ RZ(f((gamma_6,))_13) ├───┤ H ├─────────┤ X ├──■──»
#      ├─────────────────────┤├──────────────────────┤   ├───┤         └───┘┌─┴─┐»
# q_7: ┤ RX(f((beta_7,))_14) ├┤ RZ(f((gamma_7,))_15) ├───┤ H ├──────────────┤ X ├»
#      └─────┬──────────┬────┘└──────────────────────┘   └───┘              └───┘»
# q_8: ──────┤ RX(pi/2) ├────────────────────────────────────────────────────────»
#            └──────────┘                                                        »
# q_9: ──────────────────────────────────────────────────────────────────────────»
#                                                                                »
# c_0: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_1: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_2: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_3: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_4: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_5: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_6: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_7: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_8: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# c_9: ══════════════════════════════════════════════════════════════════════════»
#                                                                                »
# «                                              ┌───┐    ┌───┐               »
# «q_0: ──────────────────────────────────■──────┤ H ├────┤ H ├──■────────────»
# «                                     ┌─┴─┐┌───┴───┴───┐├───┤  │            »
# «q_1: ─────────────────────────────■──┤ X ├┤ RX(-pi/2) ├┤ H ├──┼────■───────»
# «                                  │  └───┘└───────────┘└───┘  │  ┌─┴─┐     »
# «q_2: ─────────────────────────────┼───────────────────────────┼──┤ X ├──■──»
# «                                  │                         ┌─┴─┐└───┘  │  »
# «q_3: ─────────────────────────────┼─────────────────────────┤ X ├──■────┼──»
# «                                  │                         └───┘  │  ┌─┴─┐»
# «q_4: ─────────────────────────────┼────────────────────────────────┼──┤ X ├»
# «                                  │                              ┌─┴─┐└───┘»
# «q_5: ─────────────────────────────┼──────────────────────────────┤ X ├──■──»
# «                                ┌─┴─┐┌───┐    ┌───┐              └───┘┌─┴─┐»
# «q_6: ────────────────────────■──┤ X ├┤ H ├────┤ H ├───────────────────┤ X ├»
# «     ┌────────────────────┐┌─┴─┐├───┤├───┤    └───┘                   └───┘»
# «q_7: ┤ RZ(f((tau_0,))_16) ├┤ X ├┤ H ├┤ H ├─────────────────────────────────»
# «     └────────────────────┘└───┘└───┘└───┘                                 »
# «q_8: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_9: ──────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «c_0: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_1: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_2: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_3: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_4: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_5: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_6: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_7: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_8: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_9: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                                                             ┌───┐    »
# «q_0: ─────────────────────────────────────────────────■──────┤ H ├────»
# «                                                      │      └───┘    »
# «q_1: ─────────────────────────────────────────────────┼────────■──────»
# «                                                      │      ┌─┴─┐    »
# «q_2: ────────────────────────────────────────────■────┼──────┤ X ├────»
# «                                                 │  ┌─┴─┐┌───┴───┴───┐»
# «q_3: ───────────────────────────────────────■────┼──┤ X ├┤ RX(-pi/2) ├»
# «                                            │  ┌─┴─┐├───┤└───┬───┬───┘»
# «q_4: ──■───────────────────────────────■────┼──┤ X ├┤ H ├────┤ H ├────»
# «       │                               │  ┌─┴─┐├───┤├───┤    └───┘    »
# «q_5: ──┼──────────────────────────■────┼──┤ X ├┤ H ├┤ H ├─────────────»
# «       │  ┌────────────────────┐┌─┴─┐  │  ├───┤├───┤└───┘             »
# «q_6: ──┼──┤ RZ(f((tau_1,))_17) ├┤ X ├──┼──┤ H ├┤ H ├──────────────────»
# «     ┌─┴─┐├────────────────────┤└───┘┌─┴─┐├───┤├───┤                  »
# «q_7: ┤ X ├┤ RZ(f((tau_2,))_18) ├─────┤ X ├┤ H ├┤ H ├──────────────────»
# «     └───┘└────────────────────┘     └───┘└───┘└───┘                  »
# «q_8: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_9: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «c_0: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_1: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_2: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_3: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_4: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_5: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_6: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_7: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_8: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_9: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «         ┌───┐                                                               »
# «q_0: ────┤ H ├──────────────────■────────────────────────────────────────────»
# «         ├───┤    ┌──────────┐┌─┴─┐                                          »
# «q_1: ────┤ H ├────┤ RX(pi/2) ├┤ X ├──────────────────────────────────────────»
# «     ┌───┴───┴───┐└──┬───┬───┘└───┘                                          »
# «q_2: ┤ RX(-pi/2) ├───┤ H ├──────■────────────────────────────────────────────»
# «     └┬──────────┤   └───┘    ┌─┴─┐                                          »
# «q_3: ─┤ RX(pi/2) ├────────────┤ X ├──■────────────────────────────────────■──»
# «      └──────────┘            └───┘┌─┴─┐                                ┌─┴─┐»
# «q_4: ──────────────────────────────┤ X ├──■──────────────────────────■──┤ X ├»
# «                                   └───┘┌─┴─┐┌────────────────────┐┌─┴─┐├───┤»
# «q_5: ───────────────────────────────────┤ X ├┤ RZ(f((tau_3,))_19) ├┤ X ├┤ H ├»
# «                                        └───┘└────────────────────┘└───┘└───┘»
# «q_6: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_7: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_9: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «c_0: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_1: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_2: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_3: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_4: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_5: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_6: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_7: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_8: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_9: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                        »
# «q_0: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_1: ────────────────────■──────────────────────────────────────────────»
# «              ┌───┐      │     ┌───┐                                    »
# «q_2: ──■──────┤ H ├──────┼─────┤ H ├──────────────■─────────────────────»
# «     ┌─┴─┐┌───┴───┴───┐  │  ┌──┴───┴───┐        ┌─┴─┐                   »
# ...
# «                                                                           »
# «c_0: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_1: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_2: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_3: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_4: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_5: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_6: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_7: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_8: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «c_9: ══════════════════════════════════════════════════════════════════════»
# «                                                                           »
# «                                                             ┌───┐    »
# «q_0: ─────────────────────────────────────────────────■──────┤ H ├────»
# «                                                      │      └───┘    »
# «q_1: ─────────────────────────────────────────────────┼────────■──────»
# «                                                      │      ┌─┴─┐    »
# «q_2: ────────────────────────────────────────────■────┼──────┤ X ├────»
# «                                                 │  ┌─┴─┐┌───┴───┴───┐»
# «q_3: ───────────────────────────────────────■────┼──┤ X ├┤ RX(-pi/2) ├»
# «                                            │  ┌─┴─┐├───┤└───┬───┬───┘»
# «q_4: ──■───────────────────────────────■────┼──┤ X ├┤ H ├────┤ H ├────»
# «       │                               │  ┌─┴─┐├───┤├───┤    └───┘    »
# «q_5: ──┼──────────────────────────■────┼──┤ X ├┤ H ├┤ H ├─────────────»
# «       │  ┌────────────────────┐┌─┴─┐  │  ├───┤├───┤└───┘             »
# «q_6: ──┼──┤ RZ(f((tau_1,))_17) ├┤ X ├──┼──┤ H ├┤ H ├──────────────────»
# «     ┌─┴─┐├────────────────────┤└───┘┌─┴─┐├───┤├───┤                  »
# «q_7: ┤ X ├┤ RZ(f((tau_2,))_18) ├─────┤ X ├┤ H ├┤ H ├──────────────────»
# «     └───┘└────────────────────┘     └───┘└───┘└───┘                  »
# «q_8: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «q_9: ─────────────────────────────────────────────────────────────────»
# «                                                                      »
# «c_0: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_1: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_2: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_3: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_4: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_5: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_6: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_7: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_8: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «c_9: ═════════════════════════════════════════════════════════════════»
# «                                                                      »
# «         ┌───┐                                                               »
# «q_0: ────┤ H ├──────────────────■────────────────────────────────────────────»
# «         ├───┤    ┌──────────┐┌─┴─┐                                          »
# «q_1: ────┤ H ├────┤ RX(pi/2) ├┤ X ├──────────────────────────────────────────»
# «     ┌───┴───┴───┐└──┬───┬───┘└───┘                                          »
# «q_2: ┤ RX(-pi/2) ├───┤ H ├──────■────────────────────────────────────────────»
# «     └┬──────────┤   └───┘    ┌─┴─┐                                          »
# «q_3: ─┤ RX(pi/2) ├────────────┤ X ├──■────────────────────────────────────■──»
# «      └──────────┘            └───┘┌─┴─┐                                ┌─┴─┐»
# «q_4: ──────────────────────────────┤ X ├──■──────────────────────────■──┤ X ├»
# «                                   └───┘┌─┴─┐┌────────────────────┐┌─┴─┐├───┤»
# «q_5: ───────────────────────────────────┤ X ├┤ RZ(f((tau_3,))_19) ├┤ X ├┤ H ├»
# «                                        └───┘└────────────────────┘└───┘└───┘»
# «q_6: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_7: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_9: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «c_0: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_1: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_2: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_3: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_4: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_5: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_6: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_7: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_8: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «c_9: ════════════════════════════════════════════════════════════════════════»
# «                                                                             »
# «                                                                        »
# «q_0: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_1: ────────────────────■──────────────────────────────────────────────»
# «              ┌───┐      │     ┌───┐                                    »
# «q_2: ──■──────┤ H ├──────┼─────┤ H ├──────────────■─────────────────────»
# «     ┌─┴─┐┌───┴───┴───┐  │  ┌──┴───┴───┐        ┌─┴─┐                   »
# «q_3: ┤ X ├┤ RX(-pi/2) ├──┼──┤ RX(pi/2) ├────────┤ X ├───────────■───────»
# «     ├───┤└───┬───┬───┘┌─┴─┐└──────────┘        └───┘           │       »
# «q_4: ┤ H ├────┤ H ├────┤ X ├─────■──────────────────────────────┼────■──»
# «     ├───┤    └───┘    └───┘   ┌─┴─┐    ┌────────────────────┐  │  ┌─┴─┐»
# «q_5: ┤ H ├─────────────────────┤ X ├────┤ RZ(f((tau_4,))_20) ├──┼──┤ X ├»
# «     └───┘                     └───┘    └────────────────────┘┌─┴─┐└───┘»
# «q_6: ─────────────────────────────────────────────────────────┤ X ├──■──»
# «                                                              └───┘┌─┴─┐»
# «q_7: ──────────────────────────────────────────────────────────────┤ X ├»
# «                                                                   └───┘»
# «q_8: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_9: ───────────────────────────────────────────────────────────────────»
# «                                                                        »
# «c_0: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_1: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_2: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_3: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_4: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_5: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_6: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_7: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_8: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «c_9: ═══════════════════════════════════════════════════════════════════»
# «                                                                        »
# «                                    ┌───┐                                »
# «q_0: ────────────────────────■──────┤ H ├───────────■────────────────────»
# «                           ┌─┴─┐┌───┴───┴───┐       │                    »
# «q_1: ──────────■───────────┤ X ├┤ RX(-pi/2) ├───────┼────────────────────»
# «               │           └───┘└───────────┘       │      ┌───┐         »
# «q_2: ──────────┼───────────────────────────────■────┼──────┤ H ├─────────»
# «               │                             ┌─┴─┐  │  ┌───┴───┴───┐     »
# «q_3: ──────────┼──────────────────────■──────┤ X ├──┼──┤ RX(-pi/2) ├─────»
# «             ┌─┴─┐         ┌───┐      │      └───┘  │  └───────────┘     »
# «q_4: ────────┤ X ├─────────┤ H ├──────┼─────────────┼────────────────────»
# «             ├───┤         └───┘      │             │                    »
# «q_5: ────────┤ H ├────────────────────┼─────────────┼────────────────────»
# «             └───┘                  ┌─┴─┐    ┌───┐  │                    »
# «q_6: ────────────────────────■──────┤ X ├────┤ H ├──┼────────────────────»
# «     ┌────────────────────┐┌─┴─┐    ├───┤    └───┘┌─┴─┐                  »
# «q_7: ┤ RZ(f((tau_5,))_21) ├┤ X ├────┤ H ├─────────┤ X ├──────■───────────»
# «     └────────────────────┘└───┘    └───┘         └───┘    ┌─┴─┐         »
# «q_8: ──────────────────────────────────────────────────────┤ X ├──────■──»
# «                                                           └───┘    ┌─┴─┐»
# «q_9: ───────────────────────────────────────────────────────────────┤ X ├»
# «                                                                    └───┘»
# «c_0: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_1: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_2: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_3: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_4: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_5: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_6: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_7: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_8: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «c_9: ════════════════════════════════════════════════════════════════════»
# «                                                                         »
# «
# «q_0: ──────────────────────────────────■──
# «                                       │
# «q_1: ──────────────────────────────────┼──
# «                                       │
# «q_2: ──────────────────────────────────┼──
# «                                       │
# «q_3: ──────────────────────────────────┼──
# «                                       │
# «q_4: ──────────────────────────────────┼──
# «                                       │
# «q_5: ──────────────────────────────────┼──
# «                                       │
# «q_6: ──────────────────────────────────┼──
# «                                     ┌─┴─┐
# «q_7: ─────────────────────────────■──┤ X ├
# «                                ┌─┴─┐└───┘
# «q_8: ────────────────────────■──┤ X ├─────
# «     ┌────────────────────┐┌─┴─┐└───┘
# «q_9: ┤ RZ(f((tau_0,))_22) ├┤ X ├──────────
# «     └────────────────────┘└───┘
# «c_0: ═════════════════════════════════════
# «
# «c_1: ═════════════════════════════════════
# «
# «c_2: ═════════════════════════════════════
# «
# «c_3: ═════════════════════════════════════
# «
# «c_4: ═════════════════════════════════════
# «
# «c_5: ═════════════════════════════════════
# «
# «c_6: ═════════════════════════════════════
# «
# «c_7: ═════════════════════════════════════
# «
# «c_8: ═════════════════════════════════════
# «
# «c_9: ═════════════════════════════════════
# «
# Calculated E_sim as :  -65.60216457035305
